# %%
import sys
!"{sys.executable}" -m pip install numpy pandas matplotlib seaborn
# Out:
# Requirement already satisfied: numpy in C:\Users\Anant Mishra\AppData\Local\Programs\Python\Python314\Lib\site-packages (2.5.3)
# Requirement already satisfied: pandas in C:\Users\Anant Mishra\AppData\Local\Programs\Python\Python314\Lib\site-packages (3.0.5)
# Requirement already satisfied: matplotlib in C:\Users\Anant Mishra\AppData\Local\Programs\Python\Python314\Lib\site-packages (3.11.1)
# Requirement already satisfied: seaborn in C:\Users\Anant Mishra\AppData\Local\Programs\Python\Python314\Lib\site-packages (0.13.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in C:\Users\Anant Mishra\AppData\Local\Programs\Python\Python314\Lib\site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: tzdata in C:\Users\Anant Mishra\AppData\Local\Programs\Python\Python314\Lib\site-packages (from pandas) (2026.3)
# Requirement already satisfied: contourpy>=1.0.1 in C:\Users\Anant Mishra\AppData\Local\Programs\Python\Python314\Lib\site-packages (from matplotlib) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in C:\Users\Anant Mishra\AppData\Local\Programs\Python\Python314\Lib\site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.28.2 in C:\Users\Anant Mishra\AppData\Local\Programs\Python\Python314\Lib\site-packages (from matplotlib) (4.64.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in C:\Users\Anant Mishra\AppData\Local\Programs\Python\Python314\Lib\site-packages (from matplotlib) (1.5.1)
# Requirement already satisfied: packaging>=20.0 in C:\Users\Anant Mishra\AppData\Local\Programs\Python\Python314\Lib\site-packages (from matplotlib) (26.3)
# Requirement already satisfied: pillow>=9 in C:\Users\Anant Mishra\AppData\Local\Programs\Python\Python314\Lib\site-packages (from matplotlib) (12.3.0)
# Requirement already satisfied: pyparsing>=3 in C:\Users\Anant Mishra\AppData\Local\Programs\Python\Python314\Lib\site-packages (from matplotlib) (3.3.2)
# Requirement already satisfied: six>=1.5 in C:\Users\Anant Mishra\AppData\Local\Programs\Python\Python314\Lib\site-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
#import libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import sqlite3

# %%
#1. import database/data

# %%
conn = sqlite3.connect('customer_churn.db')

sql_query = """
         SELECT name
         From  sqlite_master
         WHERE type='table';

"""

tables = pd.read_sql(sql_query,conn)


#create dataframe for each table
for table_name in tables['name']:
    df = pd.read_sql(f"SELECT * FROM {table_name}", conn)
    globals()[f"df_{table_name}" ] =df
    print(f"Created dataframe: df_{table_name}")


conn.close()
# Out:
# Created dataframe: df_db_customer
# Created dataframe: df_db_subscription
# Created dataframe: df_db_support

# %%
# Print table names and column names
conn = sqlite3.connect('customer_churn.db')

for table_name in tables['name']:
    print(f"\nTable Name: {table_name}")
    # Get column information
    columns_query = f"PRAGMA table_info({table_name});"
    columns = pd.read_sql(columns_query, conn)
    print("Columns:")
    print(columns['name'].tolist())

# Close connection
conn.close()
# Out:
# Table Name: db_customer
# Columns:
# ['customerid', 'name', 'country', 'state', 'gender', 'dob', 'interests', 'pincode']
#
# Table Name: db_subscription
# Columns:
# ['customerid', 'subscription_start_date', 'subscription_type', 'renewal_date', 'plan_type', 'contract_type', 'cancellation_date', 'cancellation_reason', 'monthly_charges', 'cltv', 'churn_score']
#
# Table Name: db_support
# Columns:
# ['customerid', 'complaint_date', 'escalations', 'csat_score', 'col_1', 'comment']

# %%
#2 data cleaning

# %%
df_db_customer.head()
df_db_customer.tail()
# Out:
#     customerid        name country          state  gender  \
# 16  0020-JDNXP       rikim   India      Meghalaya  Female
# 17  0021-IKXGC    vishakha   India      Rajasthan  Female
# 18  0022-TCJCI  raghvendra   India      Telangana    Male
# 19  0023-HGHWL     rishabh   India  Uttar Pradesh     Men
# 20  0023-UYUPN      sudevi   India    Maharashtra   Women
#
#                     dob interests pincode
# 16  1994-08-19 00:00:00       NaN    None
# 17  2000-09-02 00:00:00       NaN    None
# 18  1983-12-30 00:00:00       NaN    None
# 19  1991-05-14 00:00:00       NaN    None
# 20  1977-10-06 00:00:00       NaN    None

# %%
df_db_customer.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 21 entries, 0 to 20
# Data columns (total 8 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   customerid  21 non-null     str
#  1   name        21 non-null     str
#  2   country     18 non-null     str
#  3   state       21 non-null     str
#  4   gender      21 non-null     str
#  5   dob         21 non-null     str
#  6   interests   4 non-null      str
#  7   pincode     0 non-null      object
# dtypes: object(1), str(7)
# memory usage: 1.4+ KB

# %%
# a. rename col - name
# b. drop columns - interest and pincode
# c. change data type - dob
# d. data standarization - gender
# e. fix missing values - country

# %%
# a. rename col - name

df_db_customer.rename(columns ={'name' : 'customer_name'}, inplace= True)
df_db_customer
# Out:
#     customerid customer_name country          state  gender  \
# 0   0002-ORFBO        keshav   India    Maharashtra    Male
# 1   0003-MKNFE        raghav   India      Karnataka    Male
# 2   0004-TLHLJ        lalita   India          Delhi  Female
# 3   0011-IGKFF         mohan   India       Nagaland    Male
# 4   0013-EXCHZ          mira   India          Delhi  Female
# 5   0013-MHZWF         durga     NaN          Delhi   Women
# 6   0013-SMEOE          mina   India      Meghalaya  Female
# 7   0014-BMAQU         madan   India      Rajasthan    Male
# 8   0015-UOCOJ          maya     NaN      Kathmandu   Women
# 9   0016-QLJIS         arjun   Nepal      Kathmandu    Male
# 10  0017-DINOC         shiva   India    Maharashtra     Men
# 11  0017-IUDMW     rangadevi   India      Karnataka  Female
# 12  0018-NYROU        chitra     NaN      Telangana  Female
# 13  0019-EFAEP          raju   India      Meghalaya  Female
# 14  0019-GFNTW        Madhav   India  Uttar Pradesh     Men
# 15  0020-INWCK       parvati   India          Delhi  Female
# 16  0020-JDNXP         rikim   India      Meghalaya  Female
# 17  0021-IKXGC      vishakha   India      Rajasthan  Female
# 18  0022-TCJCI    raghvendra   India      Telangana    Male
# 19  0023-HGHWL       rishabh   India  Uttar Pradesh     Men
# 20  0023-UYUPN        sudevi   India    Maharashtra   Women
#
#                     dob interests pincode
# 0   1982-04-12 00:00:00    travel    None
# 1   1995-11-23 00:00:00       NaN    None
# 2   1978-02-15 00:00:00     movie    None
# 3   2001-08-30 00:00:00       NaN    None
# 4   1990-05-05 00:00:00     drama    None
# 5   1988-12-10 00:00:00       NaN    None
# 6   1976-09-21 00:00:00       NaN    None
# 7   1999-03-14 00:00:00       NaN    None
# 8   1985-07-07 00:00:00       NaN    None
# 9   1993-10-29 00:00:00       NaN    None
# 10  1997-01-22 00:00:00       NaN    None
# 11  1981-06-18 00:00:00       NaN    None
# 12  2004-12-01 00:00:00       NaN    None
# 13  1992-04-25 00:00:00       NaN    None
# 14  1979-11-11 00:00:00       NaN    None
# 15  1986-02-28 00:00:00       job    None
# 16  1994-08-19 00:00:00       NaN    None
# 17  2000-09-02 00:00:00       NaN    None
# 18  1983-12-30 00:00:00       NaN    None
# 19  1991-05-14 00:00:00       NaN    None
# 20  1977-10-06 00:00:00       NaN    None

# %%
# b. drop columns - interest and pincode
#df_db_customer.drop(df_db_customer.columns[-2:], axis-1)
#df_db_customer.columns[6:], axis=1)

df_db_customer.drop(columns=['interests','pincode'], inplace=True)

# %%
df_db_customer.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 21 entries, 0 to 20
# Data columns (total 6 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   customerid     21 non-null     str
#  1   customer_name  21 non-null     str
#  2   country        18 non-null     str
#  3   state          21 non-null     str
#  4   gender         21 non-null     str
#  5   dob            21 non-null     str
# dtypes: str(6)
# memory usage: 1.1 KB

# %%
# c. change data type - dob

df_db_customer['dob'] = pd.to_datetime(df_db_customer['dob'])

# %%
# d. data standarization - gender

#df_db_customer['gender'].unique()
df_db_customer['gender'] = df_db_customer['gender'].replace({'Men' : 'Male', 'Women' : 'Female'})

# %%
df_db_customer['gender'].unique()
# Out:
# <StringArray>
# ['Male', 'Female']
# Length: 2, dtype: str

# %%
# e. fix missing values - country

df_db_customer[df_db_customer['country'].isna()]
# Out:
#     customerid customer_name country      state  gender        dob
# 5   0013-MHZWF         durga     NaN      Delhi  Female 1988-12-10
# 8   0015-UOCOJ          maya     NaN  Kathmandu  Female 1985-07-07
# 12  0018-NYROU        chitra     NaN  Telangana  Female 2004-12-01

# %%
#country and state - uniquw value pair

state_country_mapping = df_db_customer.dropna(subset=['country']).set_index('state')['country'].to_dict()

df_db_customer['country'] = df_db_customer['country'].fillna(df_db_customer['state'].map(state_country_mapping))

# %%
df_db_customer[df_db_customer['country'].isna()]
# Out:
# Empty DataFrame
# Columns: [customerid, customer_name, country, state, gender, dob]
# Index: []

# %%
df_db_subscription.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 21 entries, 0 to 20
# Data columns (total 11 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   customerid               21 non-null     str
#  1   subscription_start_date  21 non-null     str
#  2   subscription_type        21 non-null     str
#  3   renewal_date             21 non-null     str
#  4   plan_type                21 non-null     str
#  5   contract_type            21 non-null     str
#  6   cancellation_date        6 non-null      str
#  7   cancellation_reason      6 non-null      str
#  8   monthly_charges          21 non-null     float64
#  9   cltv                     21 non-null     int64
#  10  churn_score              21 non-null     int64
# dtypes: float64(1), int64(2), str(8)
# memory usage: 1.9 KB

# %%
date_col = ['subscription_start_date', 'renewal_date', 'cancellation_date']
df_db_subscription[date_col] = df_db_subscription[date_col].apply(pd.to_datetime)

# %%
df_db_subscription.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 21 entries, 0 to 20
# Data columns (total 11 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   customerid               21 non-null     str
#  1   subscription_start_date  21 non-null     datetime64[us]
#  2   subscription_type        21 non-null     str
#  3   renewal_date             21 non-null     datetime64[us]
#  4   plan_type                21 non-null     str
#  5   contract_type            21 non-null     str
#  6   cancellation_date        6 non-null      datetime64[us]
#  7   cancellation_reason      6 non-null      str
#  8   monthly_charges          21 non-null     float64
#  9   cltv                     21 non-null     int64
#  10  churn_score              21 non-null     int64
# dtypes: datetime64[us](3), float64(1), int64(2), str(5)
# memory usage: 1.9 KB

# %%
df_db_support.head()
# Out:
#    customerid       complaint_date escalations  csat_score col_1  \
# 0  0003-MKNFE  2024-08-28 00:00:00           N          60  None
# 1  0003-MKNFE  2024-08-28 00:00:00           Y          10  None
# 2  0013-EXCHZ  2024-01-20 00:00:00           Y          20  None
# 3  0013-MHZWF  2025-03-18 00:00:00           N          90  None
# 4  0013-SMEOE  2024-11-01 00:00:00           N          30  None
#
#              comment
# 0      service issue
# 1     demaned refund
# 2                NaN
# 3  guidance to renew
# 4                NaN

# %%
df_db_support.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 9 entries, 0 to 8
# Data columns (total 6 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   customerid      9 non-null      str
#  1   complaint_date  9 non-null      str
#  2   escalations     9 non-null      str
#  3   csat_score      9 non-null      int64
#  4   col_1           0 non-null      object
#  5   comment         4 non-null      str
# dtypes: int64(1), object(1), str(4)
# memory usage: 564.0+ bytes

# %%
df_db_support.drop(columns=['col_1', 'comment'], inplace=True)

# %%
df_db_support['complaint_date'] = pd.to_datetime(df_db_support['complaint_date'])

df_db_support.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 9 entries, 0 to 8
# Data columns (total 4 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   customerid      9 non-null      str
#  1   complaint_date  9 non-null      datetime64[us]
#  2   escalations     9 non-null      str
#  3   csat_score      9 non-null      int64
# dtypes: datetime64[us](1), int64(1), str(2)
# memory usage: 420.0 bytes

# %%
#3. Feature Engineering and Data Analytics

# %%
#create a new columns using existing col - churn flag 
df_db_subscription['churn_flag'] = np.where(df_db_subscription['cancellation_date'].notna(), 1, 0)

# %%
df_db_subscription.head()
# Out:
#    customerid subscription_start_date subscription_type renewal_date  \
# 0  0002-ORFBO              2021-03-15          Refferal   2025-03-15
# 1  0003-MKNFE              2020-08-01              Paid   2024-08-01
# 2  0004-TLHLJ              2022-11-20           Organic   2025-11-20
# 3  0011-IGKFF              2019-05-10              Paid   2025-05-10
# 4  0013-EXCHZ              2023-01-05          Refferal   2024-01-05
#
#   plan_type contract_type cancellation_date     cancellation_reason  \
# 0  Standard        Annual               NaT                     NaN
# 1   Premium        Annual        2024-09-10  Switched to competitor
# 2     Basic       Monthly               NaT                     NaN
# 3   Premium        Annual               NaT                     NaN
# 4  Standard       Monthly        2024-02-28           Too expensive
#
#    monthly_charges  cltv  churn_score  churn_flag
# 0            13.99   627           12           0
# 1            12.99  1150           91           1
# 2             6.99   210           34           0
# 3            22.99  1725            8           0
# 4            13.99   195           88           1

# %%
#first fix support table duplicates then merge 
df = (df_db_subscription
    .merge(df_db_customer, on = 'customerid' , how= 'left')
    .merge(df_db_support, on = 'customerid', how= 'left'))

# %%
df_db_subscription.shape
# Out:
# (21, 12)

# %%
df.shape
# Out:
# (23, 20)

# %%
df_db_subscription['customerid'].nunique()
# Out:
# 21

# %%
df_db_customer['customerid'].nunique()
# Out:
# 21

# %%
df_db_support['customerid'].nunique()
# Out:
# 7

# %%
df_db_support['customerid'].size
# Out:
# 9

# %%
df_db_support
# Out:
#    customerid complaint_date escalations  csat_score
# 0  0003-MKNFE     2024-08-28           N          60
# 1  0003-MKNFE     2024-08-28           Y          10
# 2  0013-EXCHZ     2024-01-20           Y          20
# 3  0013-MHZWF     2025-03-18           N          90
# 4  0013-SMEOE     2024-11-01           N          30
# 5  0017-IUDMW     2024-04-10           Y          25
# 6  0019-EFAEP     2024-09-27           Y          30
# 7  0022-TCJCI     2024-09-13           Y          10
# 8  0022-TCJCI     2024-09-14           N          90

# %%
df_db_support['complaint_count'] = df_db_support.groupby('customerid')['customerid'].transform('count')

# %%
df_db_support = df_db_support.sort_values('complaint_date').drop_duplicates('customerid' , keep= 'last')

# %%
#merge df
df = (df_db_subscription
    .merge(df_db_customer, on = 'customerid' , how= 'left')
    .merge(df_db_support, on = 'customerid', how= 'left'))

# %%
df.shape
# Out:
# (21, 21)

# %%
df.to_csv('exported_churn_data.csv', index = False)

# %%
# Data Analysis

# %%
#1. Churn Rate

# %%
df.columns
# Out:
# Index(['customerid', 'subscription_start_date', 'subscription_type',
#        'renewal_date', 'plan_type', 'contract_type', 'cancellation_date',
#        'cancellation_reason', 'monthly_charges', 'cltv', 'churn_score',
#        'churn_flag', 'customer_name', 'country', 'state', 'gender', 'dob',
#        'complaint_date', 'escalations', 'csat_score', 'complaint_count'],
#       dtype='str')

# %%
churn_rate = df['churn_flag'].mean()*100
print("Churn Rate = ", round(churn_rate,2), "%")
# Out:
# Churn Rate =  28.57 %

# %%
#2 Retention Rate
retention_rate = 100 - churn_rate
print("Retention Rate = ", round(retention_rate,2), "%")
# Out:
# Retention Rate =  71.43 %

# %%
#3 Churn by Plan type
churn_by_plan = (df.groupby('plan_type')['churn_flag'].mean().mul(100).round(2).reset_index(name='churn_rate_pct'))
print(churn_by_plan)
# Out:
#   plan_type  churn_rate_pct
# 0     Basic           60.00
# 1   Premium           14.29
# 2  Standard           22.22

# %%
#5. ARPU - Avg Revenue per User
arpu = df['monthly_charges'].mean()
print('ARPU = ' , round(arpu,2))
# Out:
# ARPU =  18.85

# %%
#6 Avg Customer Tenure
#count of days users has used our service : cancellation date else current date
today= pd.Timestamp.today()

df['tenure_days'] = np.where(
        df['cancellation_date'].notna(), 

    (df['cancellation_date'] - df['subscription_start_date']).dt.days,

    (today - df['subscription_start_date']).dt.days
)

avg_tenure = df['tenure_days'].mean()
print("Avg Tenure (Days) =", round(avg_tenure),0)
# Out:
# Avg Tenure (Days) = 1536 0

# %%
#7 Revenue at risk - reveneue lost from churned users
revenue_at_risk = df.loc[df['churn_flag']==1, 'monthly_charges'].sum()
print("Revenue at Risk (Rs Lakhs) =", revenue_at_risk)
# Out:
# Revenue at Risk (Rs Lakhs) = 73.94

# %%
#8 Escalation Rate
escalation_rate=(df['escalations']=='Y').mean()*100
print("Escalation rate =", round(escalation_rate,2),"%")
# Out:
# Escalation rate = 19.05 %

# %%
#9 Average Complaint Rate per user
avg_complaints = df['complaint_count'].sum() / df['customerid'].nunique()
print("Avg complaints Per user = ", round(avg_complaints, 2))
# Out:
# Avg complaints Per user =  0.43

# %%
#10 Coorelation Escalation vs churn
df['escalations'] = np.where(df['escalations'] == 'Y' , 1, 0)  # encoding string to int type

corr_df = df[['escalations', 'churn_flag']].dropna()

correlation = corr_df['escalations'].corr(corr_df['churn_flag'])
print("Correlation between escalation vs churn is = ", round(correlation, 2))
# Out:
# Correlation between escalation vs churn is =  0.77

# %%
#11 churn Risk - create a column using existing tool

conditions = [
    (df['churn_score'] < 50),
    (df['churn_score'] >= 50) & (df['churn_score'] < 70),
    (df['churn_score'] >= 70)
]

choices =['low', 'med', 'high']

df['churn_risk'] =np.select(conditions,choices,default='unknown')

# %%
df[['churn_risk', 'churn_score']].head()
# Out:
#   churn_risk  churn_score
# 0        low           12
# 1       high           91
# 2        low           34
# 3        low            8
# 4       high           88

# %%
#4. Visualization using Matplotlib

# %%
df_visual = df.copy()

# %%
df_visual.columns
# Out:
# Index(['customerid', 'subscription_start_date', 'subscription_type',
#        'renewal_date', 'plan_type', 'contract_type', 'cancellation_date',
#        'cancellation_reason', 'monthly_charges', 'cltv', 'churn_score',
#        'churn_flag', 'customer_name', 'country', 'state', 'gender', 'dob',
#        'complaint_date', 'escalations', 'csat_score', 'complaint_count',
#        'tenure_days', 'churn_risk'],
#       dtype='str')

# %%
#4.1 Monthly Churn Trend (Time Series KPI)

df_visual['cancellation_month'] = df_visual['cancellation_date'].dt.to_period('M')

churn_trend = df_visual[df_visual['churn_flag'] == 1].groupby('cancellation_month').size()

plt.figure(figsize=(8,3))

plt.plot(churn_trend.index.astype(str), churn_trend.values, color='red', marker='o', linestyle='dashed', linewidth=2, markersize=12)

plt.title('Monthly Churn Trend')
plt.xlabel('Month')
plt.ylabel('churned Customers')
plt.show()

# %%
#4.2 Churn by Plan Type
churn_plan = df_visual.groupby('plan_type')['churn_flag'].mean()

colors =['Red' , 'purple' , 'grey']    #Palette

plt.figure(figsize=(7,4))

plt.bar(churn_plan.index,churn_plan.values, color = colors)

plt.show()

# %%
#4.2 Churn by State
churn_plan = df_visual.groupby('state')['churn_flag'].mean()

colors =['Red' , 'purple' , 'grey']    #Palette

plt.figure(figsize=(14,4))

plt.bar(churn_plan.index,churn_plan.values, color = colors)

plt.show()

# %%
#Visualisation using Seaborn

# %%
# encoding - convert string to numeric so that we can find corr between features
df_visual.columns
# Out:
# Index(['customerid', 'subscription_start_date', 'subscription_type',
#        'renewal_date', 'plan_type', 'contract_type', 'cancellation_date',
#        'cancellation_reason', 'monthly_charges', 'cltv', 'churn_score',
#        'churn_flag', 'customer_name', 'country', 'state', 'gender', 'dob',
#        'complaint_date', 'escalations', 'csat_score', 'complaint_count',
#        'tenure_days', 'churn_risk', 'cancellation_month'],
#       dtype='str')

# %%
 df_visual[['plan_type', 'contract_type', 'churn_score', 'churn_flag' , 'escalations', 'churn_risk']].head()
# Out:
#   plan_type contract_type  churn_score  churn_flag  escalations churn_risk
# 0  Standard        Annual           12           0            0        low
# 1   Premium        Annual           91           1            1       high
# 2     Basic       Monthly           34           0            0        low
# 3   Premium        Annual            8           0            0        low
# 4  Standard       Monthly           88           1            1       high

# %%
#incorrecct method of encoding - as numbers are not assigned based on priority

df_encoded = df_visual[['plan_type', 'contract_type', 'churn_score', 'churn_flag' , 'escalations', 'churn_risk']]

categorial_cols =['plan_type','contract_type', 'churn_risk']

for col in categorial_cols:
    df_encoded[col] = df_encoded[col].astype('category').cat.codes

# %%
df_encoded.head()
# Out:
#    plan_type  contract_type  churn_score  churn_flag  escalations  churn_risk
# 0          2              0           12           0            0           1
# 1          1              0           91           1            1           0
# 2          0              1           34           0            0           1
# 3          1              0            8           0            0           1
# 4          2              1           88           1            1           0

# %%
 #Heatmap (correlation Matrix)

sns.heatmap(df_encoded.corr(), annot=True)
# Out:
# <Axes: >

# %%
df_visual['plan_type'].unique()
# Out:
# <StringArray>
# ['Standard', 'Premium', 'Basic']
# Length: 3, dtype: str

# %%
#correcct method of encoding - as numbers are not assigned based on priority

df_encoded = df_visual[['plan_type', 'contract_type', 'churn_score', 'churn_flag' , 'escalations', 'churn_risk']]

order_mappings = {
     'plan_type' : ['Basic', 'Standard', 'Premium'],
     'contract_type' :   ['Monthly', 'Annul'],
     'churn_risk' : ['low' , 'med' , 'high']
     }

for col, order in order_mappings.items():
    df_encoded[col] = pd.Categorical(df_encoded[col].astype('category'), categories=order, ordered=True).codes

# %%
 df_visual[['plan_type', 'contract_type', 'churn_score', 'churn_flag' , 'escalations', 'churn_risk']].head()
# Out:
#   plan_type contract_type  churn_score  churn_flag  escalations churn_risk
# 0  Standard        Annual           12           0            0        low
# 1   Premium        Annual           91           1            1       high
# 2     Basic       Monthly           34           0            0        low
# 3   Premium        Annual            8           0            0        low
# 4  Standard       Monthly           88           1            1       high

# %%
df_encoded.head()
# Out:
#    plan_type  contract_type  churn_score  churn_flag  escalations  churn_risk
# 0          1             -1           12           0            0           0
# 1          2             -1           91           1            1           2
# 2          0              0           34           0            0           0
# 3          2             -1            8           0            0           0
# 4          1              0           88           1            1           2

# %%
 #Heatmap (correlation Matrix)

sns.heatmap(df_encoded.corr(), annot=True)
# Out:
# <Axes: >

# %%
 #pairplot using seaborn - to determine relationship between databses
sns.pairplot(df_encoded)

# %%
#catplt/facefrid plot - multi-dim comparision
sns.catplot(data=df_visual,
    x='plan_type',
    y='monthly_charges',
    hue='gender',
    col='churn_risk')

# %%
#pivot table

# %%
pd.pivot_table(
    df_visual,
    values='churn_flag',
    index='plan_type',
    aggfunc ='mean'
).reset_index()
# Out:
#   plan_type  churn_flag
# 0     Basic    0.600000
# 1   Premium    0.142857
# 2  Standard    0.222222

# %%
df_visual.columns
# Out:
# Index(['customerid', 'subscription_start_date', 'subscription_type',
#        'renewal_date', 'plan_type', 'contract_type', 'cancellation_date',
#        'cancellation_reason', 'monthly_charges', 'cltv', 'churn_score',
#        'churn_flag', 'customer_name', 'country', 'state', 'gender', 'dob',
#        'complaint_date', 'escalations', 'csat_score', 'complaint_count',
#        'tenure_days', 'churn_risk', 'cancellation_month'],
#       dtype='str')

# %%
pd.pivot_table(
    df_visual,
    values=['monthly_charges', 'customerid', 'churn_flag'],
    index='plan_type',
    aggfunc = {
        'monthly_charges' : 'sum',
        'customerid' : 'nunique',
        'churn_flag' : 'mean',
    }
)
# Out:
#            churn_flag  customerid  monthly_charges
# plan_type
# Basic        0.600000           5            52.95
# Premium      0.142857           7           218.93
# Standard     0.222222           9           123.91

# %%
#working with sql in Python (Pandas)

# %%
import sqlite3

conn = sqlite3.connect("test_database.sqlite")
#create table
conn.execute("""
    CREATE TABLE IF NOT EXISTS users (
        first_name TEXT,
        country TEXT,
        budget INTEGER
    )
""")
#save and commit 
conn.commit()

# %%
#insert data

cursor = conn.cursor()
#write sql queries to insert records in sql table 
cursor.execute("""
    INSERT INTO users VALUES
        ('ANANT', 'India', 5000),
        ('RISHABH', 'Germany', 2500),
        ('ADITYA', 'India', 3500)
""")
#commit and save
conn.commit()

print("Data Inserted Successfully")
# Out:
# Data Inserted Successfully

# %%
#check inserted data in table 
conn = sqlite3.connect("test_database.sqlite")
query= """SELECT * FROM users"""

df_results = pd.read_sql(query,conn)

df_results.head()
# Out:
#   first_name  country  budget
# 0      ANANT    India    5000
# 1    RISHABH  Germany    2500
# 2     ADITYA    India    3500
# 3      ANANT    India    5000
# 4    RISHABH  Germany    2500

# %%
#aggregation 
query = """
             SELECT country , sum(budget) as total_budget
             From users
             GROUP BY country
"""
df_agg = pd.read_sql(query,conn)
df_agg
# Out:
#    country  total_budget
# 0  Germany         25000
# 1    India         85000

# %%
#always close the conn with db once the task is over
conn.close()
